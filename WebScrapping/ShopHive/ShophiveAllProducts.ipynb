# %% [markdown]
# # Required Function for feature extraction:

# %%
import urllib.request
from bs4 import BeautifulSoup
from collections import defaultdict
import time



def get_title(new_soup):
    try:
      title = new_soup.find("span",attrs={"class": "base", "data-ui-id":"page-title-wrapper","itemprop": "name"}).text.strip()
      if title :
        return title
      else:

         return "N/A"
    except Exception as e:
        print(f"Error in get_title: {e}")
        return "N/A"



def get_price(new_soup):
    try:
        price_element = new_soup.find("span", class_="price")
        if price_element:
            return price_element.text.strip()
        else:
            return "N/A"
    except Exception as e:
        print(f"Error in get_price: {e}")
        return "N/A"





def get_sku(new_soup):
  try:
     sku = new_soup.find("div",attrs={"class": "value","itemprop":"sku"}).text.strip()
     if sku:
      return sku
     else:
      return 'N/A'
  except Exception as e:
      print(f"Error in get_sku: {e}")
      return "N/A"
  return sku

def get_subcat(new_soup):
  try:
    sub_cat = new_soup.find('div',attrs={'class': 'cat-links'}).find('a').text.strip()
    if sub_cat:
      return sub_cat
    else:
      return 'N/A'
  except Exception as e:
      print(f"Error in get_subcat: {e}")
      return "N/A"


def get_all_features(soup):
    specs = {}
    try:
        table = soup.find("table", class_="data table additional-attributes")
        if table:
            rows = table.find_all("tr")
            for row in rows:
                key = row.find("th").text.strip().lower().replace(" ", "_")
                value = row.find("td").text.strip()
                specs[key] = value
    except Exception as e:
        print(f"[Spec error] {e}")
    return specs

# %% [markdown]
# # Main Code:

# %%
import urllib.request
from bs4 import BeautifulSoup
import json
import time
import csv


url = 'https://www.shophive.com/'
headers = {'User-Agent': 'Mozilla/5.0'}
req = urllib.request.Request(url, headers=headers)
html = urllib.request.urlopen(req).read()
soup = BeautifulSoup(html, "html.parser")

menu = soup.find("ul", class_="smartmenu magebig-nav")
category_links = {}

top_items = menu.find_all("li", class_="level0")
for item in top_items:
    category_tag = item.find("a", class_="level-top")
    if category_tag and category_tag.has_attr("href"):
        try:
            category_name = category_tag.find("span").contents[0].strip()
        except:
            category_name = category_tag.get_text(strip=True)
        category_href = category_tag["href"].strip()
        if category_href.startswith("http"):
            category_links[category_name] = category_href


data = []
visited_urls = set()

for category, base_url in category_links.items():
    print(f"\nCategory: {category}")
    page = 1

    while True:
        paged_url = f"{base_url}?p={page}"
        print(f"  Page {page}: {paged_url}")
        try:
            req = urllib.request.Request(paged_url, headers=headers)
            html = urllib.request.urlopen(req, timeout=10).read()
            page_soup = BeautifulSoup(html, "html.parser")
            product_tags = page_soup.find_all("a", class_="product-item-link")

            if not product_tags:
                print("  No more products.")
                break

            for tag in product_tags:
                try:
                    product_url = tag['href']
                    if product_url in visited_urls:
                        continue
                    visited_urls.add(product_url)

                    req = urllib.request.Request(product_url, headers=headers)
                    product_html = urllib.request.urlopen(req).read()
                    new_soup = BeautifulSoup(product_html, "html.parser")

                    time.sleep(1.5)

                    product = {
                        "category": category,
                        "subcategory": get_subcat(new_soup),
                        "title": get_title(new_soup),
                        "price": get_price(new_soup),
                        "url": product_url,
                        "sku": get_sku(new_soup)

                    }
                    specs = get_all_features(new_soup)
                    product.update(specs)

                    print(f"     - Product: {product['title']}")
                    data.append(product)

                except Exception as inner_e:
                    print(f"  [Product Error]: {inner_e}")
                    continue

            page += 1
            time.sleep(2.5)

        except Exception as e:
            print(f"  [Page Error]: {e}")
            break

    time.sleep(2)


all_keys = set()
for item in data:
    all_keys.update(item.keys())
fieldnames = sorted(list(all_keys))



with open("products.json", "w", encoding="utf-8") as f:
    json.dump(data, f, indent=4, ensure_ascii=False)

print("Saved to 'products.json'")
# Out:
# Category: Apple
#   Page 1: https://www.shophive.com/apple?p=1
#      - Product: Apple Vision Pro 512GB
#      - Product: Apple iTunes Gift Card 15$
#      - Product: Apple iTunes Gift Card 50$
#      - Product: Apple iTunes Gift Card 25$
#      - Product: Apple iTunes Gift Card 100$
#      - Product: Apple 60W MagSafe 2 Power Adapter for MacBook Pro (MD565B)
#      - Product: Apple 60W MagSafe 1 Power Adapter for MacBook and 13-inch MacBook Pro MC461B
#      - Product: Apple iTunes Gift Card 10$
#   [Product Error]: HTTP Error 500: Internal Server Error
#      - Product: Apple 45W MagSafe 2 Power Adapter for MacBook Air MD592LL
#      - Product: Apple Silicone Case for 9.7-inch iPad Pro - Charcoal Gray
#      - Product: Mi Type-C to Lightning Cable 1m
#      - Product: Apple Magic Keyboard for iPad Pro 11 inch 3rd generation and iPad Air 4th generation, 5th Gen US English
#      - Product: Apple TV 3rd Generation 64GB 4K Wifi (MN873LL)
#      - Product: Apple iMac M1 Chip 24 inch 8GB 256GB SSD
#      - Product: Apple iMac M1 Chip 24 inch 8GB 512GB SSD
#   Page 2: https://www.shophive.com/apple?p=2
#      - Product: Apple 87W USB-C Power Adapter MNF82LL/A
#      - Product: Apple Smart Keyboard for Ipad 10.2" & 10.5" (MPTL2)
#      - Product: Apple Pencil 2nd Gen MU8F2
#      - Product: Apple Smart Keyboard for 12.9" inch iPad Pro MU8H2
#      - Product: Targus Aluminium Series Lightning to USB Cable - Silver
#      - Product: Targus Aluminium Series Lightning to USB Cable - Gold
#      - Product: Targus Lightning To USB Charging Cable - 1m
#      - Product: Apple 30W USB-C Power Adapter MY1W2B
#      - Product: Travel Blue Usb To Apple Lightning Cable
#      - Product: Apple HomePod Mini
#      - Product: Apple MagSafe Charger MHXH3
#      - Product: Ugreen Lightning to 3.5mm Jack Adapter 10cm - 30756
#      - Product: Ugreen 90 Degree Lightning To USB A Cable -  60521
#      - Product: Apple 20W USB-C 3 Pin Power Adapter
#      - Product: WiWU Skin Pro II Synthetic Leather Laptop Sleeve
#      - Product: Apple Mac Pro Tower 8‑core Xeon 32GB 256GB SSD Z0W3
#   Page 3: https://www.shophive.com/apple?p=3
#      - Product: Apple Mac Pro Rack Mount 8‑core Xeon 32GB 256GB SSD Z0YZ
#      - Product: Apple Smart Keyboard Folio Case for iPad Pro 12.9-inch 3rd/4th Gen MXNL2
#      - Product: ESR iPad Pro 12.9 2020 Paper Feel Clear Matte Film
#      - Product: Apple 44mm Atlantic Blue Braided Solo Loop Size 10
#      - Product: Apple 44mm Charcoal Braided Solo Loop Size 10
#      - Product: Apple USB Type-C Digital AV Multiport Adapter - MUF82
#      - Product: Apple Smart Keyboard For 10.5" iPad Pro MPl2ZA
#      - Product: Apple pencil Tips 4 Pack
#      - Product: Ugreen 10396 Micro USB 2.0 OTG Adapter Cable
#      - Product: Apple 96W USB-C Power Adapter MX0J2AM
#      - Product: Targus Cleanvu Cleaning Pads For Ipad
#      - Product: Targus Stylus for iPad (Bone White)
#      - Product: Apple Magic Trackpad lightning connecter (MK2D3)
#      - Product: Apple Magic Keyboard for iPad Pro 12.9‑inch (5th & 6th generation) - US English - Black (MJQK3)
#      - Product: Apple Magic Keyboard for iPad Pro 12.9‑inch (5th generation) - US English - white (MJQL3)
#      - Product: Ugreen 80822 1M Lightning To USB 2.0 A Male Cable Black
#   Page 4: https://www.shophive.com/apple?p=4
#      - Product: Apple USB-C To Lightning Cable 1M MM0A3
#      - Product: Moshi 16" Umbra MacBook Pro Privacy Screen Protector 99MO085018
#      - Product: Dux Ducis Keyboard with Protective Case for iPad Pro 12.9 (2020/2021)
#      - Product: Baseus Superior Series Type c To iPhone 20W 2m Cable
#      - Product: Baseus Zinc Magnetic iPhone Safe 2.4A 1m Cable
#      - Product: Baseus Zinc Magnetic Safe Type-C To iPhone 20W 1m Cable
#      - Product: Baseus Zinc Magnetic Safe Type-C To iPhone 20W 2m Cable
#      - Product: Ugreen MFi Lightning to USB Charging Cable (1M White)
#      - Product: Ugreen 50944 Apple Watch Magnetic Charging
#      - Product: Targus Aluminium Series Lightning to USB Cable – Black
#      - Product: Moshi iGlaze Hardshell Case for MacBook Pro (13-inch, 2020) 99MO124002
#      - Product: Targus ring buckle lightning cable
#      - Product: Apple USB-C to 3.5 mm Headphone Jack Adapter MU7E2AM
#      - Product: UGreen 40705 Protective Cable Sleeve Plug Cover
#      - Product: UGreen 60764 MFI Elbow USB Type C To Lightning Cable – 1.5M
#      - Product: Apple MagSafe Battery Pack
#   Page 5: https://www.shophive.com/apple?p=5
#      - Product: Apple iPad Mini 6 8.3" 64GB WIFI (2021)
#      - Product: Apple iPad Mini 6 8.3" 256GB WIFI (2021)
#      - Product: Baseus L52 3-in-1 iP Male to Dual iP & 3.5mm Female Adapter
#      - Product: Ipad Air Tempered Glass Screen Protector Clear
#      - Product: Coeetci Universal PC MacBook Case For Macbook Air 13
#      - Product: Coteetci PC Frosted Case Tpu Frame Protection MacBook Air 13
#      - Product: Coteetci Universal PC MacBook Case For Macbook Pro 15"
#      - Product: Hardshell Case for Macbook Air 13”
#      - Product: ESR Apple iPad 9th Gen 2021 Ascend Hard Shell Case – Clear
#      - Product: ESR iPad Pro 12.9 2021 Rebound Magnetic Smart Case
#      - Product: Mutural Design Flip Case For Apple iPad Pro 12.9 (2021)
#      - Product: Apple Magic Mouse 3 White Multi-Touch Surface MK2E3
#      - Product: Spigen Apple AirPods Pro Case Rugged Armor ASD00540 Matte Black
#      - Product: ESR Apple iPhone 12 Pro Camera Lens HD Protector Black
#      - Product: Apple Mac Studio Empower station 32GB 512GB SSD
#      - Product: Apple Mac Studio Empower Station M1 Ultra Chip 64GB 1TB SSD
#   Page 6: https://www.shophive.com/apple?p=6
#      - Product: Apple 27" Studio Display 2022
#      - Product: Tronsmart LAC01 4ft Lightning Cable
#      - Product: Tronsmart LTA13 Double Braided Lightning Cable
#      - Product: Tronsmart Lta14 Nylon 4ft Lightning Cable Grey
#      - Product: Apple USB-C to Lightning 2m Cable MQGH2ZA
#      - Product: Baseus Superior Fast Charging USB To Lightning Cable 2m
#      - Product: Baseus Cafule Series Metal Data Cable Type-C to iP 20W 2M
#      - Product: Anker PowerLine III USB-C To Lightning White 3ft Cable (A8832H21)
#      - Product: Anker PowerLine III USB-C To Lightning White 6ft Cable (A8833H21)
#      - Product: Usams U43 SJ406 Type c to Lightning PD Fast Charging Data Cable 1.2M
#      - Product: Usams U38 SJ405 Type-C to Lightning PD Fast Charging Data Cable - 1m
#      - Product: Usams US-SJ518 Type C To Lightning Smart Power-off 20W PD Cable
#      - Product: Usams US-SJ500 U68 Lightning Charging & Data Cable 1m
#      - Product: Usams US-SJ487 U64 Lightning Aluminum Alloy Charging & Data Cable 1.2m
#      - Product: Usams US-SJ543 U78 8 Pin Aluminum Alloy Digital Display Charging Data Cable 1.2m -Black
#      - Product: Usams US-SJ523 U71 Type C to Lightning 20W PD Fast Charging Data Cable 3m
#   Page 7: https://www.shophive.com/apple?p=7
#      - Product: Usams US-SJ391 U41 Lightning Braided Data & Charging Cable 1m
#      - Product: Baseus Crystal Shine Type C to iP Cable 20W 1.2m
#      - Product: Onten Hd708 Micro Plus Mini Hdmi to Hdmi F/M Adapter
#      - Product: ESR iPad Pro 12.9″/11″ 2022 / 2021/ 2020 Camera Lens HD Protector 2 PACK – Black
#      - Product: Apple Pencil 1st Generation With Lightning adapter (MQLY3ZM)
#      - Product: Spigen Apple Watch Band for 49 mm / 45mm / 44mm / 42mm Lite Fit
#      - Product: Apple iPad 10 10.9" Wifi 64GB (2022)
#      - Product: Apple Case For iPad 10.9"
#      - Product: iPad 9 Book Cover 10.2"
#      - Product: iPad Pro 11 inches (2020) Book Case
#      - Product: iPad Pro 12.9 Inc Book Cover
#      - Product: Apple iPad Pro M2 Chip 12.9" 128GB Wifi
#      - Product: Apple iPad Pro M2 Chip 12.9" 256GB Wifi
#      - Product: Apple Magic Keyboard Folio for iPad 10th generation - US English
#      - Product: Apple Magic Keyboard with Touch ID and Numeric Keypad (MMMR3LL)
#      - Product: Apple Watch Ultra 49mm Alpine Loop - Small Starp
#   Page 8: https://www.shophive.com/apple?p=8
#      - Product: Apple Watch Ultra 49mm Alpine Loop - Large Strap
#      - Product: Apple Watch Ultra 49mm Trail Loop - S/M Strap
#      - Product: Apple Watch Ultra 49mm Trail Loop - M/L Strap
#      - Product: Apple HomePod 2nd Generation
#      - Product: Apple Watch SE 44mm Gen 2 Silver Case With Strom Blue Sports Band
#      - Product: Apple AirPods Pro 2nd Gen (2023) with MagSafe Charging Case USB‑C (MTJV3AM)
#      - Product: Apple Watch SE 44mm Gen 2 Midnight Case With Midnight Sports Band
#      - Product: Apple Watch SE 44mm Gen 2 Starlight Case With Starlight Sports Band
#      - Product: Apple Mac Studio Empower Station M2 Max Chip 32GB 512GB SSD
#      - Product: Apple Mac Studio Empower Station M2 Ultra Chip 64GB 1TB SSD
#      - Product: Apple Mac Pro M2 Ultra Chip
#      - Product: Apple 20W 2 Pin USB-C Power Adapter
#      - Product: Spigen iPhone 15 Pro Ultra Hybrid Case Matte Black - ACS06713
#      - Product: Spigen iPhone 15 Pro Ultra Hybrid Case Natural Titanium – ACS07214
#      - Product: Spigen iPhone 15 Pro Max / 15 Pro / 14 Pro Max / 14 Pro Camera Lens Protector GlasTR EZ Fit Optik Pro Black Titanium 2 PACK – AGL05205
#      - Product: Spigen iPhone 15 Pro Thin Fit Case Gunmetal – ACS06687
#   Page 9: https://www.shophive.com/apple?p=9
#      - Product: Spigen iPhone 15 Pro Ultra MagFit Case Zero One – ACS06721
#      - Product: Spigen iPhone 15 Pro Airskin Hybrid Case Clear – ACS06697
#      - Product: Spigen iPhone 15 Pro Optik Armor MagFit Case Black – ACS07184
#      - Product: Spigen iPhone 15 Pro Max Ultra Hybrid Case Sky Crystal – ACS07046
#      - Product: Spigen iPhone 15 Pro Max Cryo Armor Case Cryo Blue – ACS06603
#      - Product: Spigen iPhone 15 Pro Mag Armor MagFit Case Matte Black – ACS06736
#      - Product: Spigen iPhone 15 Pro Rugged Armor MagFit Case Matte Black – ACS06703
#      - Product: Spigen iPhone 15 Pro Ultra MagFit Anti-Yellowing Case Zero One White – ACS07036
#      - Product: Spigen iPhone 15 Pro Max Cryo Armor Case Cryo Red – ACS06604
#      - Product: Spigen iPhone 15 Pro Style Armor MFit Case Classic Silver – ACS06748
#      - Product: Spigen iPhone 15 Pro Classic C1 MagFit Case Graphite – ACS06742
#      - Product: Spigen iPhone 15 Pro Style Armor Magfit Case Midnight Indigo – ACS06747
#      - Product: Spigen iPhone 15 Pro Ultra MagFit Case Zero One Natural Titanium – ACS07216
#      - Product: Apple Magic Keyboard for iPad Pro 13‑inch M4 US English Black MWR53
#      - Product: Apple Magic Keyboard for iPad Pro 13‑inch M4 US English White MWR43
#      - Product: Yolo YDC-03C Lightning Data Cable
#   Page 10: https://www.shophive.com/apple?p=10
#      - Product: Yolo YDC-O4C Type C to Lightning Cable
#      - Product: Choetech AUX005 Lightning To 3.5MM Headphone Adapter White
#      - Product: Magic Keyboard for iPad Pro 11-inch M4 US English White MWR03
#      - Product: Apple Magic Keyboard for iPad Pro 11‑inch M4 US English Black MWR23
#      - Product: Apple iMac M3 Chip 24 Inch 8GB 256GB SSD (MQR93) Silver
#      - Product: Apple iMac M3 Chip 24 Inch 8GB 256GB SSD (MQRD3) Pink
#      - Product: Apple iMac M3 Chip 24 Inch 8GB 256GB SSD (MQRA3) Green
#      - Product: Apple iMac M3 Chip 24 Inch 8GB 512GB SSD (MQRR3) Blue
#      - Product: Apple iMac M3 Chip 24 Inch 8GB 512GB SSD (MQRK3) Silver
#      - Product: Apple iMac M3 Chip 24 Inch 16GB 512GB SSD (Z197) Blue
#      - Product: Apple iMac M3 Chip 24 Inch 16GB 512GB SSD (Z195) Silver
#      - Product: Apple IMac M3 Chip 24 Inch 16GB 1TB SSD (Z197) Blue
#      - Product: Apple IMac M3 Chip 24 Inch 16GB 1TB SSD (Z195) Silver
#      - Product: ESR Classic Hybrid Halolock Case For iPhone 15 Pro
#      - Product: Apple iPhone 15 Pro FineWoven Case with MagSafe
#      - Product: Apple iPhone 15 Pro Max FineWoven Case with MagSafe
#   Page 11: https://www.shophive.com/apple?p=11
#      - Product: Apple Magic Keyboard US English (MK2A3)
#      - Product: USAMS US-SJ538 USB-C to Lightning Aluminum Alloy Colorful Lights Fast Charging Data Cable 1.2m
#      - Product: USAMS US-SJ311 U26 Lighting Charging Data Cable 1m
#      - Product: UGreen 18W USB Fast Charger With USB-C Cable
#      - Product: Apple Pencil USB-C Gen 3 (MUWA3)
#      - Product: Choetech USB to Lightning Apple Mfi Certified 1.8m Cable
#      - Product: Choetech USB-C to Lightning Nylon Braided MFi Certified 3M Cable
#      - Product: Choetech USB-C to Lightning Nylon Braided MFi Certified Cable 1.2m
#      - Product: Choetech 15W Fast Wireless Charger Stand with Wall Charger 1.2m Cable
#      - Product: Apple iPad Pro M4 Chip 13" 256GB Wifi
#      - Product: Apple iPad Air 2024 6th Gen 11" 128GB Wi-Fi
#      - Product: Apple IPad Pro M4 Chip 11" 512GB Wifi
#      - Product: Apple IPad Pro M4 Chip 13" 512GB Wifi
#      - Product: Apple IPad Pro M4 Chip 11" 1TB Wifi
#      - Product: Apple IPad Pro M4 Chip 13" 1TB Wifi
#      - Product: Apple IPad Pro M4 Chip 11" 2TB Wifi
#   Page 12: https://www.shophive.com/apple?p=12
#      - Product: Apple IPad Pro M4 Chip 13" 2TB Wifi
#      - Product: Apple TV 3rd Generation 128GB 4K Wifi + Ethernet (MN893LL)
#   [Product Error]: HTTP Error 500: Internal Server Error
#   [Product Error]: HTTP Error 500: Internal Server Error
#      - Product: Spigen iPhone 15 Pro Ultra Hybrid Case Clear - ACS06707
#      - Product: Spigen iPhone 15 Pro Max Ultra Hybrid Case Navy Blue – ACS06573
#      - Product: Spigen iPhone 15 Pro Max Ultra Hybrid Case Matte Black – ACS06570
#      - Product: Spigen iPhone 15 Pro Max Optik Armor MagFit Case Black – ACS06599
#      - Product: Spigen iPhone 15 Pro Liquid Crystal Case Clear – ACS06699
#      - Product: Spigen iPhone 15 Pro Max Ultra MagFit Anti-Yellowing Case Zero One White – ACS07034
#      - Product: Spigen iPhone 15 Pro Ultra MagFit Case White – ACS06715
#      - Product: Samsung 45w Charger 3 Pin with 1.8m Cable Black
#      - Product: Apple EarPods USB-C (MTJY3AM)
#      - Product: Apple iPhone 15 Pro Max 256GB PTA Approved
#      - Product: Apple iPhone 15 Pro 128GB PTA Approved
#      - Product: Apple iPhone 15 Pro 256GB PTA Approved
#   Page 13: https://www.shophive.com/apple?p=13
#      - Product: Apple iPhone 15 Pro 512GB PTA Approved
#      - Product: Apple iPhone 15 Pro 1TB PTA Approved
#      - Product: Apple iPhone 15 512GB PTA Approved
#      - Product: Baseus Unbreakable Series Fast Charging Data Cable Type-C to iP 20W 2m Cluster Black
#      - Product: Apple iMac M3 Chip 24 Inch 8GB 256GB SSD (MQRC3) Blue
#      - Product: Eouro Transparent Case for iPhone 15 Pro Max
#      - Product: Eouro Transparent Case for iPhone 15 Pro
#      - Product: Anker 310 USB C to Lightning Cable – 0.9m
#      - Product: Samsung 25w 2Pin Adaper With Type C2C Cable
#      - Product: Anker Powerport III 20W Cube With Charging Cable (B2149K21)
#      - Product: Apple iPhone 16 Transparent Case
#      - Product: Apple iPhone 16 Pro Max Screen Protector
#      - Product: Apple iPhone 16 Pro Transparent Case
#      - Product: Apple iPhone 16 Pro Max Transparent Case
#      - Product: Apple iPhone 16 Pro Screen Protector
#      - Product: Apple iPhone 16 Screen Protector
#   Page 14: https://www.shophive.com/apple?p=14
#      - Product: Samsung 25w 3Pin Adaper With Type-C 2 C Cable
#      - Product: Apple iPad Mini 7 8.3'' 128GB Wifi (2024)
#      - Product: Apple iPad Mini 7 8.3'' 256GB Wifi (2024)
#      - Product: Apple Macbook Pro M4 Pro 2024 14.2" 24GB 512GB SSD Silver MX2E3
#      - Product: Apple Macbook Pro M4 Pro 2024 14.2" 24GB 1TB SSD Space Black MX2J3
#      - Product: Apple Macbook Pro M4 Pro 2024 14.2" 24GB 1TB SSD Silver MX2F3
#      - Product: Apple Macbook Pro M4 Pro 2024 16.2" 24GB 512GB SSD Space Black MX2X3
#      - Product: Apple Macbook Pro M4 Pro 2024 16.2" 24GB 512GB SSD Silver MX2T3
#      - Product: Apple Macbook Pro M4 Max 2024 16.2" 36GB 1TB SSD Silver MX2V3
#      - Product: Apple Mac Mini M4 Chip 2024 16GB 256GB SSD Silver - MU9D3
#      - Product: Apple Mac Mini M4 Chip 2024 24GB 512GB SSD Silver - MCYT4
#   [Product Error]: HTTP Error 500: Internal Server Error
#      - Product: Apple iMac 2024 M4 chip 24 Inch 16GB 256GB
#      - Product: Apple iMac 2024 M4 chip 24 Inch 16GB 512GB SSD
#      - Product: Apple iMac 2024 M4 chip 24 Inch 24GB 512GB SSD
#      - Product: Apple Mac Mini M4 2024 16GB 512GB SSD Silver - MU9E3
#   Page 15: https://www.shophive.com/apple?p=15
#      - Product: Apple iPhone 16 Plus Transparent Case
#      - Product: Amaze A24 Swift Series USB to Lightning 2.4A Cable 1m
#      - Product: Amaze A44 Ultra Charge Type C to Lightning Cable 20W 1m
#      - Product: Spigen iPhone 16 Plus Thin Fit MagFit Case ACS08060 Black
#      - Product: Spigen iPhone 16 Pro Max Ultra Hybrid MagFit Case – ACS08791 Neo One
#      - Product: Spigen iPhone 16 Pro Max Ultra Hybrid T Case – ACS08506 Graphite
#      - Product: Spigen iPhone 16 Pro Rugged Armor MagFit Case – ACS08115 Black
#      - Product: Spigen iPhone 16 Pro Ultra Hybrid MagFit Case ACS08792  – Neo One
#      - Product: Spigen iPhone 16 Thin Fit MagFit Case – ACS08186 Black
#      - Product: Spigen Apple Watch Series 10 46mm Lite Fit Pro Case With Band – ACS08609 Matte Black
#      - Product: Spigen Apple Watch Series 10 46mm Rugged Armor Case – ACS08597 Matte Black
#      - Product: Spigen Apple Watch Series 10 46mm Rugged Armor Pro Case With Band
#      - Product: Spigen iPhone 16 Pro Max / 16 Pro / 15 Pro Max / 15 Pro Camera Lens Protector GlasTR EZ Fit Optik Pro – AGL07163 Natural Titanium 2 PACK
#      - Product: Spigen iPhone 16 Pro Max / 16 Pro / 15 Pro Max / 15 Pro Camera Lens Protector GlasTR EZ Fit Optik Pro – AGL07165 White Titanium 2 PACK
#      - Product: Spigen iPhone 16 Pro Max / 16 Pro / 15 Pro Max / 15 Pro Camera Lens Protector GlasTR EZ Fit Optik Pro – AGL08862 Desert Titanium 2 PACK
#      - Product: Aukey Iphone 15 Pro 6.1-inch Silicon Magnetic Liquid Phone Case Compatible with MagSafe – PC-GJ10C
#   Page 16: https://www.shophive.com/apple?p=16
#      - Product: Aukey Iphone 15 Pro Max 6.7-inch Silicon Magnetic Liquid Phone Case Compatible with MagSafe – PC-GJ10D
#      - Product: Apple iPhone 16 Plus Screen Protector
#      - Product: Apple iPad Air M3 2025 7th Gen 11" 128GB Wi-Fi
#      - Product: Apple iPad Air M3 2025 7th Gen 11" 256GB Wi-Fi
#      - Product: Apple iPad Air M3 2025 7th Gen 11" 512GB Wi-Fi
#      - Product: Apple iPad Air M3 2025 7th Gen 11" 1TB Wi-Fi
#      - Product: Apple iPad Air M3 2025 7th Gen 13" 128GB Wi-Fi
#      - Product: Apple iPad Air M3 2025 7th Gen 13" 256GB Wi-Fi
#      - Product: Apple iPad Air M3 2025 7th Gen 13" 512GB Wi-Fi
#      - Product: Apple iPad Air M3 2025 7th Gen 13" 1TB Wi-Fi
#      - Product: Apple iPad 11 11" Wifi 256GB (2025)
#      - Product: Apple iPad 11 11" Wifi 512GB (2025)
#      - Product: Apple Mac Studio M3 Ultra Chip 2025 96GB 1TB SSD Silver - MU973
#      - Product: Apple Mac Studio M4 Max Chip 2025 36GB 512GB SSD Silver - MU963
#      - Product: Apple 35W Dual USB-C Port Power Adapter
#      - Product: Romoss CB1713 PD Data Cable 20W Fast Charging Type c to lightning Cable 1M
#   Page 17: https://www.shophive.com/apple?p=17
#      - Product: Romoss CB1713 PD Data Cable 20W Fast Type C to Lightning Charging Cable 2M
#      - Product: Romoss CB17B Type C To iPhone Cable 1m
#      - Product: Romoss CB17B Type C To iPhone Cable 2M
#      - Product: Remax RC-094i Kerolla Lightning Charging Data Cable
#      - Product: Anker A81A2 310 Type C To iPhone 1.8m 6ft Cable
#      - Product: Anker 641 Flow 3ft USB-C to Lightning Silicone Cable
#      - Product: Anker A81A1 Type C to iPhone Data Cable 1M
#      - Product: Anker A7139 Pencil Capacitive Stylus Pen
#      - Product: Baseus Habitat Series Type C to iPhone 20W Fast Charging Cable 2m
#      - Product: Baseus Habitat Series 20W Type C To iPhone 1m Fast Charging Cable
#      - Product: Baseus Silky Series Fast Charging Cable Type C to IP 20W Moon White
#      - Product: ESR iPad Air 13 M2 / M3 Flip Hybrid Case Pencil Holder Black
#      - Product: ESR iPad Air 13 M2 / M3 Magnetic Privacy Screen Protector 1 Pack
#      - Product: ESR iPad Air 13 M2 / M3 Tempered Glass Screen Protector 1 Pack
#      - Product: ESR Magsafe Wallet & Stand made from Vegan Leather Black Carbon Fiber
#      - Product: ESR Skygrip Airplane Phone Holder
#   Page 18: https://www.shophive.com/apple?p=18
#      - Product: ESR iPad 11 Gen A16 / 10 Gen A14 Paper Feel Magnetic Screen Protector
#      - Product: ESR iPad 11 Gen A16 / 10 Gen A14 UltraFit Armorite Screen Protector 2 Packs
#      - Product: Apple Multi Touch Surface Magic Mouse USB C White (MXK53)
#      - Product: Spigen Apple iPhone 15 Pro Max Thin Fit Case Black – ACS06544
#      - Product: Spigen Apple Watch Screen Protector ProFlex 44mm Models 6/SE/5/4 with Auto Alignment Kit Clear 2 PACK – AFL01220
#      - Product: ESR iPad Pro11/13 2024 ,iPad Pro 12.9″ / 11″ 2022 / 2021 / 2020 Camera Lens HD Protector 2 PACK - Black
#      - Product: Aukey MFI Braided Nylon USB C To Lightning Cable 1m – CB-CL1
#   [Product Error]: HTTP Error 500: Internal Server Error
#      - Product: ESR Paper-Feel Screen Protector Compatible with iPad Air 11" Air 10.9" iPad Pro 11" – 2 Pack
#      - Product: ESR Paper-Feel Screen Protector Compatible with iPad Air 13 iPad Pro 12.9" – 2 Pack
#      - Product: ESR Paper-Feel Screen Protector Compatible with iPad Pro 11 (2024) – 2 Pack
#      - Product: ESR Paper-Feel Screen Protector Compatible with iPad Pro 13 (2024) – 2 Pack
#      - Product: ESR Tempered-Glass Screen Protector Compatible with iPad Air 13" iPad Pro 12.9" – 1 Pack
#      - Product: ESR Magnetic Privacy Screen Protector Compatible with iPad Air 11 (2024) Air 10.9 & Pro 11 – 1 Pack
#      - Product: Anker 310 C-Lightning 1.8m 6ft Cable White
#      - Product: Choetech Usb C To Lightning 18W/30W Mfi Certified Cable 1.2m (IP0040)
#   Page 19: https://www.shophive.com/apple?p=19
#      - Product: WIWU 3 in 1 Live Broadcast Adapter
#      - Product: WIWU LT01 Pro 2 in 1 Lightning Adapter
#      - Product: WIWU Wi-C031 Concise Adapter Pack
#      - Product: WIWU Combo Keyboard For Ipad
#      - Product: WIWU Detachable 11inch Magnetic Case For iPad
#      - Product: WIWU 2 IN 1 Magnetic Case For iPad 10.9" 2022 10th Gen
#      - Product: WIWU Mecha Protective Case For iPad 10.2''/10.5''
#      - Product: WIWU Mecha Protective Case For iPad 10.9''/11''
#      - Product: WIWU iVista Tempered Glass Protector For iPad
#      - Product: WIWU 2 IN 1 Magnetic Case For iPad 10.2''/10.5''
#      - Product: WIWU RZ-01 Razor Ultra Light Wireless Keyboard For iPad
#      - Product: WIWU WP401 Type C to Lightning Cable
#      - Product: WIWU YQ01 Vitality USB C To Lightning Cable
#      - Product: WIWU YP 06 Lightning To Audio Cable
#      - Product: Apple 140W USB-C Power Adapter
#      - Product: WIWU Parallel Hardshell iPad Mini 6 Bag
#   Page 20: https://www.shophive.com/apple?p=20
#      - Product: WIWU Pencil W Pro For iPad
#      - Product: WIWU Calf Skin Genuine Leather Airpods Pro Case
#      - Product: WIWU Mecha Airpods Pro Case Green
#      - Product: WIWU Mecha Airpods Case Green
#      - Product: WIWU Mecha Airpods Pro 3 Case
#      - Product: ESR Classic Hybrid Back Case Compatible with iPad Air 13 2024 - Clear
#      - Product: ESR Classic Hybrid Back Case Compatible with iPad Air 13 2024 – Clear Black
#      - Product: ESR Classic Hybrid Case Compatible with iPad Pro 13 2024 – Clear
#      - Product: ESR Classic Hybrid Case Compatible with iPad Pro 13 2024 – Clear Black
#      - Product: ESR Rebound Hybrid Case 360 Compatible with iPad Air 13 2024 – Black
#      - Product: ESR Rebound Hybrid Case 360 Compatible with iPad Air 13 2024 – Grey
#      - Product: ESR Shift Magnetic Case Compatible with iPad Air 13 2024 – Black
#      - Product: ESR Zero Soft Case Compatible with iPad Air 11 2024 Air 10.9 (5th/4th Gen) – Frosted Clear
#      - Product: ESR iPad Air 11 6th Gen 2024 Shift Magnetic Case Compatible With iPad Air 5 / Air 4 – Black
#      - Product: Apple AirPods 4 2024 (MXP63)
#      - Product: Apple AirPods Max With Active Noise Cancellation 2024
#   Page 21: https://www.shophive.com/apple?p=21
#      - Product: Apple Watch Ultra 2 Natural Titanium 49mm Case With Navy Ocean Band - 2024
#      - Product: Apple Watch Ultra 2 Black Titanium 49mm Case With Navy Ocean Band - 2024
#      - Product: Apple Watch Ultra 2 Natural Titanium 49mm Case With Black Ocean Band - 2024
#      - Product: Apple Watch Ultra 2 Black Titanium 49mm Case With Black Ocean Band - 2024
#      - Product: Apple AirTag 4 Pack
#      - Product: Benks Ultra Shield HD Screen Protector For iPhone 16 Pro Max (0.3/Black)
#      - Product: Benks Lucent Pro Magnetic Drop-Resistant Protective Case T1 For iPhone16 Pro Max Transparent
#      - Product: Benks Lucent Pro Magnetic Drop Resistant Protective Case T1 iPhone 16 Transparent
#      - Product: Benks Ultra Shield HD Screen Protector For iPhone 16 Pro (0.3/Black)
#      - Product: Benks Magnetic Lucid Armor Protective Case For iPhone 16 Pro Max Black
#      - Product: Benks Glass Warrior Sapphire Coating Screen Protector For iPhone 16 Pro Max (0.3/Black)
#      - Product: Benks Montage ArmorPro Case built with Kevlar 600D for iPhone 16 Pro Max with TPU Edge
#      - Product: Benks Lucent Pro Phone Transparent Case for iPhone 16 Pro Max
#      - Product: Benks Magnetic Lucid Armor Protective Case For iPhone 16 Pro Black
#      - Product: Benks Montage ArmorPro Case built with Kevlar 600D for iPhone 16 Pro with TPU Edge
#      - Product: Benks New York Phone Case for iPhone 16 Pro Max
#   Page 22: https://www.shophive.com/apple?p=22
#      - Product: Benks DR Sapphire Lens Protector For iPhone 16 Pro/16 Pro Max (Black/3Pcs)
#      - Product: Benks Lucent Pro Magnetic Drop Resistant Protective Case T1 iPhone 16 Plus Transparent
#      - Product: Benks Glass Warrior Lens Protector For iPhone 16/16 Plus (Transparent/2Pcs)
#      - Product: Benks Multi-Fold Protective Case iPad Pro 13 Urban Magnetic Case (2024)
#      - Product: Benks Joy Touch Matte Screen Protector For iPhone 16 Pro Max (0.3 Black Installation Kit)
#      - Product: Benks Lucid Magnetic Armor Phone Case for iPhone 16
#      - Product: Benks Glass Warrior Lens Protector For iPhone 16 Pro/16 Pro Max (Black 3Pcs)
#      - Product: Benks Multi Fold Protective Case iPad Air 11 Urban Magnetic Case (2024)
#      - Product: Benks Multi-Fold Protective Case iPad Pro 11 Urban Magnetic Case (2024)
#      - Product: Benks DR Sapphire Lens Protector For iPhone 16 Pro/16 Pro Max (Silver/3Pcs)
#      - Product: Benks Paper Like Matte Screen Protector For iPad Pro 11（2024）
#      - Product: Benks Armor Air Case built with Kevlar 600D for iPhone 16 Pro Max
#      - Product: Benks Armor Air Case built with Kevlar 600D for iPhone 16 Plus
#      - Product: Benks Paper Like Screen Protector For iPad Pro 13（2024）
#      - Product: Benks Ultra Shield HD Screen Protector For iPhone 16 Pro (0.4 Black)
#      - Product: Benks Armor PRO Case built with Kevlar 600D for iPhone 16 Pro Max
#   Page 23: https://www.shophive.com/apple?p=23
#      - Product: Benks Ultra Shield HD Screen Protector For iPhone 16 Plus  (0.4/Black)
#      - Product: Benks Armor PRO Case built with Kevlar 600D for iPhone 16 Pro
#      - Product: Benks Paper Like Screen Protector For iPad Air 11（2024）
#      - Product: Benks Paper Like Screen Protector For iPad Air 13（2024）
#      - Product: Benks Armor Air Case built with Kevlar 600D for iPhone 16
#      - Product: Benks Vintage Vegan Leather Case for iPhone 15 Pro Brown
#      - Product: Benks Vintage Vegan Leather Case for iPhone 15 Pro Max Brown
#      - Product: Apple iPhone 16 Pro Clear Case with MagSafe
#      - Product: Apple iPhone 16 Pro Max Clear Case with MagSafe
#      - Product: Apple iPhone 16 Pro Silicone Case with MagSafe
#      - Product: Apple iPhone 16 Pro Max Silicone Case with MagSafe
#      - Product: Spigen iPhone 16 Pro Max /16 Pro /15 Pro Max /15 Pro /14 Pro Max/14 Pro Camera Lens Protector GlasTR EZ Fit Optik Pro Black Titanium  2 PACK
#      - Product: Spigen iPhone 16 Liquid Air Case – Matte Black
#      - Product: Spigen iPhone 16 Plus / 15 Plus GLAS.tR EZ Fit Sensor Protected Clear - 2 Pack
#      - Product: Spigen iPhone 16 Plus Liquid Air Case Matte Black
#      - Product: Spigen iPhone 16 Pro Max GLAS.tR EZ Fit Sensor Protected  Clear – 2 Pack
#   Page 24: https://www.shophive.com/apple?p=24
#      - Product: Spigen iPhone 16 Pro Ultra Hybrid Case Matte Black
#      - Product: Spigen iPhone 16 Rugged Armor Case Matte Black
#      - Product: Spigen iPhone 16 Ultra Hybrid Case Clear
#      - Product: Spigen iPhone 16 Ultra Hybrid Case Matte Black
#      - Product: Apple 70W USB-C Power Adapter
#      - Product: Apple Thunderbolt 5 USB C Pro Cable 1m
#      - Product: Apple USB C to 3.5mm Audio Cable 1.2m
#      - Product: Usams US-SJ448 U55 Lightning Fast Charging Micro USB Data Cable 1m
#      - Product: Apple Magic Trackpad USB‑C Multi Touch Surface (MXK93AM)
#      - Product: QCY DC06 Quick Charge USB A To Lightening Cable
#      - Product: Westpoint WP-352 Fast Charging Type-C To Lightning PD Cable
#      - Product: Apple AirTag
#      - Product: Spigen iPhone 16 Pro Max Ultra Hybrid MagFit Case White
#      - Product: Aukey iPhone 15 Pro 6.1-inch Clear View Transparent Magnetic Clear Phone Case Compatible with MagSafe PC-TM10C
#      - Product: Aukey iPhone 15 Pro 6.1-inch Super Clear View High-Clarity Tempered Glass Screen Protector – SP-GT10C
#      - Product: Aukey iPhone 15 Pro 6.1-inch Super Tough Corning Gorilla Glass Screen Protector – SP-GT20C
#   Page 25: https://www.shophive.com/apple?p=25
#   [Product Error]: HTTP Error 500: Internal Server Error
#      - Product: Aukey iPhone 15 Pro Max 6.7-inch Super Clear View High-Clarity Tempered Glass Screen Protector – SP-GT10D
#      - Product: Aukey iPhone 15 Pro Max 6.7-inch Super Tough Corning Gorilla Glass Screen Protector – SP-GT20D
#      - Product: Apple Watch SE 40mm Gen 2 Silver Case With Strom Blue Sports Band
#      - Product: Apple Watch SE 40mm Gen 2 Starlight Case With Starlight Sports Band
#      - Product: Apple Macbook Air 2025 M4 13.6" 16GB 512GB SSD
#      - Product: Apple Macbook Pro M4 Max 2024 16.2" 36GB 1TB SSD Space Black MX303
#      - Product: Apple Macbook Pro M4 Max 2024 14.2" 36GB 1TB SSD Silver MX2G3
#      - Product: Apple Macbook Pro M4 2024 14.2" 16GB 512GB SSD Space Black MW2U3
#      - Product: Apple Macbook Pro M4 2024 14.2" 16GB 512GB SSD Silver MW2W3
#      - Product: Apple Macbook Pro M4 Pro 2024 16.2" 48GB 512GB SSD Space Black MX2Y3
#      - Product: Apple Macbook Pro M4 Pro 2024 16.2" 48GB 512GB SSD Silver MX2U3
#      - Product: Apple Macbook Pro M4 Max 2024 16.2" 48GB 1TB SSD Silver MX2W3
#      - Product: Apple Macbook Pro M4 Max 2024 16.2" 48GB 1TB SSD Space Black MX313
#      - Product: Apple Macbook Pro M4 Pro 2024 14.2" 24GB 512GB SSD Space Black MX2H3
#      - Product: Apple 240W USB-C To USB-C Charge Cable (2m)
#   Page 26: https://www.shophive.com/apple?p=26
#      - Product: Apple EarPods with Lightning Connector MMTN2ZM
#      - Product: Apple Macbook Pro M4 Max 2024 14.2" 36GB 1TB SSD Space Black MX2K3
#      - Product: Apple Macbook Air 2025 M4 15.3" 16GB 256GB SSD
#      - Product: Apple Macbook Air 2025 M4 13.6" 24GB 512GB SSD
#      - Product: Apple Macbook Air 2025 M4 15.3" 16GB 512GB SSD
#      - Product: Apple Macbook Air 2025 M4 15.3" 24GB 512GB SSD
#      - Product: Apple iPad 11 11" Wifi 128GB (2025)
#      - Product: Apple iPad 10 10.9" Wifi 256GB (2022)
#      - Product: Apple iPad Pro M4 Chip 11" 256GB Wifi
#      - Product: Octo Ultra Book Case For iPad 10 & 9 (Black)
#      - Product: QCY DC08 30W Quick Charge PD Type-C Lightning Cable
#      - Product: Apple AirPods 4 2024 With Active Noise Cancelation (MXP93)
#      - Product: Apple IPhone 14 128GB PTA Approved
#      - Product: Apple Macbook Pro M4 2024 14.2" 16GB 1TB SSD Space Black MW2V3
#      - Product: Apple Macbook Pro M4 2024 14.2" 16GB 1TB SSD Silver MW2X3
#      - Product: Apple Macbook Pro M4 2024 14.2" 24GB 1TB SSD Space Black MCX04
#   Page 27: https://www.shophive.com/apple?p=27
#      - Product: Apple Macbook Pro M4 2024 14.2" 24GB 1TB SSD Silver MCX14
#      - Product: Apple iPhone 11 128GB PTA Approved
#      - Product: Apple USB C Magic Keyboard MXCL3
#      - Product: Apple Watch Series 10 46mm Silver Aluminium Case With Denim Sports Band
#      - Product: Apple Watch Series 10 46mm Rose Gold Aluminium Case With Starlight Sports Band
#      - Product: Apple Watch Series 10 46mm Jet Black Aluminium Case With Black Sports Band
#      - Product: Apple Watch Series 10 42mm Jet Black Aluminium Case With Black Sports Band
#      - Product: Apple Watch Series 10 42mm Silver Aluminium Case With Denim Sports Band
#      - Product: Apple Watch Series 10 42mm Rose Gold Aluminium Case With Starlight Sports Band
#      - Product: Apple Watch SE 40mm Gen 2 Midnight Case With Midnight Sports Band
#      - Product: Apple Pencil Pro (MX2D3AM)
#      - Product: Spigen iPhone 15 Pro GLAS.tR EZ Fit Privacy Screen Protector Case Friendly 2 PACK – AGL06894
#      - Product: Spigen iPhone 15 Pro Max Thin Fit Case Mute Blue – ACS06550
#      - Product: ESR Apple iPhone 12 mini Ice Shield Case
#      - Product: ESR Apple iPhone 12 / iPhone 12 mini Camera Lens HD Protector 2 Pack
#      - Product: ESR Apple iPhone 12 mini Alliance Tough Case
#   Page 28: https://www.shophive.com/apple?p=28
#      - Product: ESR Apple iPhone 12 Pro Camera Lens HD Protector 1 Pack – Black
#      - Product: Apple Macbook Air 2024 M3 13.6" 16GB 256GB MC8G4 Space Grey
#      - Product: Apple iPhone 16e 128GB
#      - Product: Apple iPhone 16e 512GB
#      - Product: Apple iPhone 16 128GB PTA Approved
#   [Product Error]: HTTP Error 500: Internal Server Error
#      - Product: Apple iPhone 16 512GB PTA Approved
#      - Product: Apple iPhone 16 Plus 128GB PTA Approved
#      - Product: Apple iPhone 16 Plus 256GB PTA Approved
#      - Product: Apple iPhone 16e 256GB
#      - Product: Apple iPhone 16 Pro 256GB PTA Approved
#      - Product: Apple iPhone 16 Plus 512GB PTA Approved
#      - Product: Apple iPhone 16 Pro 128GB PTA Approved
#      - Product: Apple iPhone 16 Pro 512GB PTA Approved
#      - Product: Apple iPhone 16 Pro 1TB PTA Approved
#      - Product: Apple iPhone 16 Pro Max 256GB PTA Approved
#   Page 29: https://www.shophive.com/apple?p=29
#   [Page Error]: HTTP Error 500: Internal Server Error
#
# Category: Mobile Phones
#   Page 1: https://www.shophive.com/mobile-phones?p=1
#      - Product: Amaze A22 Swift Series USB to Micro 2.4A Cable 1m
#      - Product: Amaze A230 Nexus 10000MAH Power Bank 22.5W
#      - Product: Amaze A232 Nexus 20000MAH Power Bank 22.5W
#      - Product: Amaze A235 Nexus Smart 10000MAH Power Bank 22.5W
#      - Product: Amaze A245 Maglite Wireless 10000MAH Power Bank 20W
#      - Product: Amaze A40 Ultra Charge Type C To Type C Cable 60W 1M
#      - Product: Amaze A42 Ultra Charge Type C to Type C Cable 100w 1m
#      - Product: Anker 20W PD 312 Adapter A2678
#      - Product: Anker 240W 6ft Type C to C Cable Braided
#      - Product: Anker 30w Travel Adapter 4 In 1 Ultra Expanded Power For Traveling
#      - Product: Anker 312 A2678611 20W II Charger
#      - Product: Anker 321 MagGo Battery PowerCore 5000mah Magnetic Power Bank
#      - Product: Anker 322 NYLON USB-C to USB-C 0.9m Cable White
#      - Product: Anker 322 USB-C to USB-C 60W Cable 1.8m - A81F6H11
#      - Product: Anker 323 2 Port Usb C + Usb A Car Charger - A2735G11
#      - Product: Anker 323 Charger (33W)
#   Page 2: https://www.shophive.com/mobile-phones?p=2
#      - Product: Anker 323 USB C PowerCore PIQ Power Bank 10000Mah
#      - Product: Anker 334 MagGo Magnetic 10000mAh Power Bank A1642
#      - Product: Anker 335 67W 2 Type C 1 USB Powerful Car Charger
#      - Product: Anker 33W PD+USB Fast Charger A2331
#      - Product: Anker 511 20W Nano Charger
#      - Product: Anker 511 Nano Pro 20w Charger
#      - Product: Anker 511 PowerCore Fusion 30W 5000mah Power Bank + Adapter
#      - Product: Anker 515 PowerPort III Pod Lite 65w Compact Fast Charger A2718
#      - Product: Anker 521 40W Nano Pro Charger A2038
#      - Product: Anker 535 67W Car Charger (A2736)
#      - Product: Anker 535 Car Charger 3 Ports 2 Usb C + 1 Usb A with Usb C Cable (1m) - B2731HA1
#      - Product: Anker 67W GaN Prime Fast Adapter 2C+U A2669
#      - Product: Anker 735 Charger (GaNPrime 65W)
#      - Product: Anker 735 Nano II 65W Charger Black
#      - Product: Anker 737 PowerCore 24K Gen2 24000mah Power Bank (A1289011)
#      - Product: Anker A1259 Nano 10000MAH 30W Power Bank
#   Page 3: https://www.shophive.com/mobile-phones?p=3
#      - Product: Anker A1339 Prime 2-in-1 65W 9600mAh Power bank
#      - Product: Anker A1647 22.5W 20000mAh Built In USB C Cable Power Bank
#      - Product: Anker A1652611 7.5W 10000mAH Maggo Power Bank With Stand
#      - Product: Anker A2039 47w Type-C Charger (Nano 3)
#      - Product: Anker A2147 30W iPhone Fast Charger
#      - Product: Anker A2148 737 GanPrime 120W 2C+U Charger
#      - Product: Anker A2149 20W Mini Cube Power Port III USB C Fast Charger With Foldable Plug
#      - Product: Anker A2310H11 PowerDrive 2 - Without Cable
#      - Product: Anker A2633G22 PowerPort III Nano 20W  PowerIQ 3.0 USB-C Charger
#      - Product: Anker A2698 30w USB C Quick Charger
#      - Product: Anker A2699 Zolo Mini 20w Quick Wall Charger
#      - Product: Anker A2727 PowerDrive 2 Alloy Metal Mini Car Charger
#      - Product: Anker A2732 PowerDrive PD+2 Dual Port High Speed 35W Car Charger
#      - Product: Anker A2737 Nano 167.5W 3 Ports Car Charger With Type C to Type C Cable 1M
#      - Product: Anker A7123H12 3.5 Mm Male To Male Audio Cable Black
#      - Product: Anker A80F6 USB-C to USB-C 240W Cable Bio Nylon 1.8m
#   Page 4: https://www.shophive.com/mobile-phones?p=4
#      - Product: Anker A81E1 310 USB C to C Fast Charging Cable 0.9meter 60W/3A
#      - Product: Anker A81E2 310 USB C to C Fast Charging Cable 1.8M 60W/3A
#      - Product: Anker A81F5 322 Type C To Type C 0.9m 3ft Cable Black
#      - Product: Anker A9514 Powercore PD Redux 18W 10000mAh Dual Output Power Bank
#      - Product: Anker B2557 MagGo Foldable 3 In 1 Wireless Charging Station
#      - Product: Anker B2697 ZOLO 140W GaN 4 Port Charger
#      - Product: Anker Charger 20W 2-Port Charger White
#      - Product: Anker Nano 12w Lightning Connector Power Bank
#      - Product: Anker Nano 22.5w Type-C Connector Power Bank
#      - Product: Anker PowerCore III Sense 10000Mah Portable Power Bank Steel Blue
#      - Product: Anker PowerLine 3ft USB-C to USB 3.0 Cable A8163H21 - White
#      - Product: Anker PowerLine Select USB Cable With Lightning Connector 6ft Cable - A8013H11
#      - Product: Anker PowerPort Atom III 2 Ports Wall Charger - A2322G21
#      - Product: Anker PowerPort III 20W Cube USB-C Charger
#      - Product: Anker PowerPort III 20W Cube USB-C Charger – Black (A2149K11)
#      - Product: Anker PowerWave Magnetic 2 In 1 Stand Lite Wireless Charger
#   Page 5: https://www.shophive.com/mobile-phones?p=5
#      - Product: Anker Prime 100W GaN Wall Charger (3 Ports)
#      - Product: Anker Prime 200W Power Bank 20,000mAh
#      - Product: Anker Zolo Mini 30w Quick Wall Charger
#      - Product: Anker Zolo Type C to Type C 240W Braided Fast Charging Data Cable 1.5m
#      - Product: Apple 60W USB-C 1m Charge Cable
#      - Product: Apple MagSafe Duo Charger
#      - Product: Apple Thunderbolt 3 (USB‑C) Cable (0.8 m) MQ4H2
#      - Product: Apple USB-C Charge Cable (2 m) MLL82ZA
#      - Product: Apple USB-C to MagSafe 3 Cable 2m MLYV3AM
#      - Product: Apple Watch Magnetic Charging Cable (2 m) - MU9H2
#      - Product: Aukey Braided Nylon USB 3.1 USB A To C Cable (6.6ft)
#      - Product: Aukey  Car Charger with Quick Charge 3.0 & 2 USB Ports
#      - Product: Aukey Car Charger With Quick Charge 3.0 & 2 USB Ports CC-T11
#      - Product: Aukey MagLink 38.5wh 10,000mah Magnetic Wireless Charging Power Bank with Metal Foldable Stand – PB-MS02
#      - Product: Aukey PA-R2S Swift Duo PD40W 2 Port PD Wall Charger
#      - Product: Aukey USB C Cable 3.95 feet Braided USB 3.0 Type C Cable Fast Charge Black – CB-AC1
#   Page 6: https://www.shophive.com/mobile-phones?p=6
#      - Product: Awei C-708 PD 45W Car Charger
#      - Product: Awei C-843 Mini Car Charger Fast Charger
#      - Product: Awei C-853 150cm Front/Rear Seat Car Charger
#      - Product: Awei P10K 3 in 1 Portable Power Bank 10000mAh
#      - Product: Awei P88K Portable Power Bank 10000mAh
#      - Product: Baseus 150W High Power Car Inverter
#      - Product: Baseus 3.5A 4 In 1 M+L+C+C Fast Charging Data Cable
#      - Product: Baseus 4 Port 120W USB Car Quick PPS Multi-Port Fast Car Charger
#      - Product: Baseus Adaman Metal 20,000mah 22.5W Digital Display Power Bank
#      - Product: Baseus Bipow Digital Display 20,000mah 15W Power Bank
#      - Product: Baseus Bipow Digital Display Power bank 10000mAh 15W Black
#      - Product: Baseus Cafule Cable USB to Type C 2A 2M
#      - Product: Baseus Cafule Cable USB to Type C 3A 1M
#      - Product: Baseus Cafule Micro USB Charging Cable 2.4A 2M
#      - Product: Baseus Cafule Type C 2M USB Cable
#      - Product: Baseus Compact Super20W Dual Port USB + Type C Quick Charger
#   Page 7: https://www.shophive.com/mobile-phones?p=7
#      - Product: Baseus Compact U+C 20W Quick Charger Black
#      - Product: Baseus Cube Gravity Car Mount Holder
#      - Product: Baseus Cube Pro Fast Charger 1C 30W EU Black
#      - Product: Baseus Dynamic Series Fast Charging Data Cable Type-C to Type-C 100W 1m
#      - Product: Baseus Explorer Series 10,000mah 22.5W Digital Display Quick Charge Power Bank
#      - Product: Baseus Flash Series 3 One for three Fast Charging Cable Type C to C+C+C 100W
#      - Product: Baseus Flash Series 3 One for three Fast Charging Cable Type C To C+C+L 100W
#      - Product: Baseus Flash Series Two for Three Fast Charging Cable U+C to M+L+C 100W
#      - Product: Baseus Flash Series Two Type c To 3 In 1 100W Cable 1.2M
#      - Product: Baseus Flash Series Ⅱ One For Three 100W 1.2m Fast Charging Data Cable USB To M+L+C Black
#      - Product: Baseus GaN 5 Fast Charger 1C 25W US Cluster Black
#      - Product: Baseus GaN2 Pro Quick Charger 2C+2U 100W US Black
#      - Product: Baseus GaN5 Fast Charger Mini 1C 30W EU Black
#      - Product: Baseus GaN5 Pro Fast Charger C+C 40W EU Black
#      - Product: Baseus GaN5S 1C 20W EU Fast Charger Cluster Black
#      - Product: Baseus Golden Contactor 60W Max Dual USB Fast Car Charger
#   Page 8: https://www.shophive.com/mobile-phones?p=8
#      - Product: Baseus Golden Contactor Pro 2x USB C 40W Car Charger Gray
#      - Product: Baseus Golden Contactor Pro 40W U+C Dual Quick Car Charger Dark Gray
#      - Product: Baseus Magic Series 45W 6A Car Charger U+U Black
#      - Product: Baseus Magnetic Mini Wireless Fast Charging 10000mah 20W
#      - Product: Baseus Magnetic Mini Wireless Power Bank 20000mAh 20W
#      - Product: Baseus Micro USB Yiven 2A 1.5m Cable Black
#      - Product: Baseus Multi Port 152.5W Fast Car Charger 2C+U Set Cluster Black
#      - Product: Baseus Palm 1C 30W US Fast Charger
#      - Product: Baseus Palm 1C 30W US Fast Charger With Type C To Type C Cable 1m
#      - Product: Baseus PicoGo GaN 1C 45W US Fast Charger Cosmic Black
#      - Product: Baseus Power Bank 5000mAh Compact Type C Edition 20W
#      - Product: Baseus Qpow Pro+ 20000mAh 22.5W Type-C Digital Display Fast Charge Power Bank
#      - Product: Baseus S09 T Type Bluetooth FM Modulator Car Charger
#      - Product: Baseus Share Together 120W 3x USB + Type C PPS Quick Car Charger
#      - Product: Baseus Silky Series Fast Charging Cable Type C to Type C 100W
#      - Product: Baseus Star Lord Digital Display Fast Charging Power Bank 30000mAh 30W Cluster Black
#   Page 9: https://www.shophive.com/mobile-phones?p=9
#      - Product: Baseus StarSpeed Fast Charging Data Cable USB to M+L+C 3.5A 1.2m Black
#      - Product: Baseus Super Si Pro C+U 30W US Quick Charger Black
#      - Product: Baseus Super Si Quick Charger 1C 25W EU Black
#      - Product: Baseus Superior 2A Fast Charging Micro Cable 1m
#      - Product: Baseus Superior Series Fast Charging Data Cable Type-C to Type-C 100W 2M
#      - Product: Baseus Type-C Rapid 3-In-1 1.5m Cable
#   [Product Error]: HTTP Error 500: Internal Server Error
#      - Product: Baseus UltraControl Pro Series Clamp Type Car Holder Set
#      - Product: Baseus USB C to USB C PD QC Cable 100W 5A 2M
#      - Product: Beats Auxiliary Cable with Mic - B0521 - Red
#      - Product: Belkin 3 in 1 Magnetic Foldable Wireless Charger with Qi2 15W
#      - Product: Benks Armor Power 60W Type C To Type C  Braided Cable
#      - Product: Benks C30 SE 30W Dual Port Fast Car Charger
#      - Product: Benks CZ03 Magnetic Wireless Car Charger Tarnish Stand
#      - Product: Benks PA46 Ultimate-S 20W PD Mini Charger White
#      - Product: Benks W12 On-Go 3 in 1 Foldable Magnetic Wireless Charger
#   Page 10: https://www.shophive.com/mobile-phones?p=10
#      - Product: Benks W13 Juice Pod 3-in-1 15W Foldable Magnetic Wireless Charger Station
#      - Product: Choetech 140W 2x USB-C 2x USB-A  4-Port Quick Charging GaN Wall Charger
#      - Product: Choetech 2 In 1 Wireless Charger 10W Max Wireless Charging Pad For Phones and Galaxy Watch (T570-S)
#      - Product: Choetech 25W USB A To Type C Fast Charging Cable (AC0013)
#      - Product: Choetech 60W PD 3.0 Type C USB C Fast Charging Foldable Adapter
#      - Product: Choetech 60W USB C Cable USB C Wall Charger
#   [Product Error]: HTTP Error 500: Internal Server Error
#      - Product: Choetech AC0004 USB A To Type C Cable 2.0 Fast Charging & Data Sync Cable 10ft 3m
#      - Product: Choetech B653 PD 45W 20000mAh Power bank
#      - Product: Choetech B728 10000mAh PD 22.5W with Digital Display Power Bank
#      - Product: Choetech B729 20000mAh PD 22.5W with Digital Display Power Bank
#      - Product: Choetech C0051 QC 3.0 Dual USB-A Ports 36W  Car Charger
#      - Product: Choetech T521-F 15W Wireless Fast Car Charger
#      - Product: Choetech TC0006 Dual USB QC 3.0 USB A + PD 30W Type C USB Fast Car Charger Black
#      - Product: Choetech TC0008 PD 40W Dual USB C Ports Fast Car Charger Black
#      - Product: Choetech TC0010 63W Dual USB-C 45W + 18W Fast Car Charger
#   Page 11: https://www.shophive.com/mobile-phones?p=11
#      - Product: Choetech Ultra Fast 130W Gan 3 USB-C 1 USB-A Power Charger Adapter
#      - Product: Choetech USB Type C USB Type C 3A cable 3m
#      - Product: ESR Galaxy S23 Ultra Shock Armor Kickstand Case with 1 FREE Screen Guard – Clear Black
#      - Product: ESR Galaxy S23 Ultra Shock Armor Kickstand Case with 2 FREE Screen Guard – Clear Green
#      - Product: ESR Qi2 3 in 1 Travel Wireless Charging Set HaloLock Black
#      - Product: ESR Qi2 3 in 1 Watch Wireless Charging Set US Plug With CryoBoost Black
#      - Product: Infinix GT 30 Pro 12GB 512GB
#      - Product: Infinix Hot 50 8GB 128GB
#      - Product: Infinix Hot 50 Pro 8GB 128GB
#      - Product: Infinix Hot 50 Pro Plus 8GB 256GB
#      - Product: Infinix Hot 50i 6GB 128GB
#      - Product: Infinix Hot 60i
#      - Product: Infinix Note 30 VIP 8GB 256GB
#      - Product: Infinix Note 40 Pro 12GB 256GB
#      - Product: Infinix Note 50 8GB 256GB
#      - Product: Infinix Note 50 Pro 12GB 256GB
#   Page 12: https://www.shophive.com/mobile-phones?p=12
#      - Product: Infinix Smart 10 Plus
#      - Product: Infinix Smart 9 4GB 128GB
#      - Product: Infinix Smart 9 HD 4GB 64GB
#      - Product: Infinix XC05 Kit 20W Fast Wall Charger With Type C To Type C 3A Cable
#      - Product: Infinix XC06 Kit 30W Fast Wall Charger With Type C To Type C 3A Cable
#      - Product: Infinix XDC33 Type C Cable
#      - Product: Infinix XDL13 Type C To iPhone Cable
#      - Product: Infinix XP10 10000mah Power Bank
#      - Product: Infinix XP20 20000mAh 15W Power Bank
#      - Product: Infinix Zero 40 4G 8GB 256GB
#      - Product: Infinix Zero Flip
#      - Product: Itel A50 4GB 64GB
#      - Product: Itel A80 8GB 128GB
#      - Product: Itel A90 4GB 128GB
#      - Product: Itel CITY 100 6GB 128GB
#      - Product: Itel IPP-85 30,000mAh Large Power Bank
#   Page 13: https://www.shophive.com/mobile-phones?p=13
#      - Product: Itel IPP-85L 27,000mAh High Power Bank
#      - Product: Itel P55 8GB 128GB
#      - Product: Itel P65C 4GB 128GB
#      - Product: Itel Power P70 4GB 128GB
#      - Product: Itel S23 Plus 8GB 256GB
#      - Product: Itel S24 8GB 128GB
#      - Product: Itel S24 8GB 256GB
#      - Product: Itel S25 6GB 128GB
#      - Product: Itel S25 8GB 128GB
#      - Product: Itel S25 Ultra 8GB 256GB
#      - Product: Itel Star100PF 10,000mAh Super Charge Power Bank
#      - Product: Itel Star200 20,000mAh Super Power Bank Black
#      - Product: JoyRoom  JR-QP191 10000mah 22.5W Fast Charging Power Bank with LCD display
#      - Product: Ldnio A4405 4 Ports Travel USB Wall Charger with LED Light 4A
#      - Product: Ldnio A6573C 65W Multi Ports Desktop Charging Station
# ...
#   [Product Error]: HTTP Error 500: Internal Server Error
#      - Product: LG GR-267SLRL 21 CFT Side by Side No Frost Refrigerator
#      - Product: PEL PRLP-6460 Life Pro 12 CFT Top Mount Refrigerator
#   Page 31: https://www.shophive.com/appliances?p=31
#      - Product: PEL PRGD-2200 7 CFT Refrigerator Maroon Prism
#      - Product: PEL 9 CFT PRGD-2350 Pattre Mirror Refrigerator
#      - Product: PEL PRLP-2350 Life Pro 9 CFT Top Mount Refrigerator
#      - Product: Philips 5400 Series Fully Automatic Espresso Machines - EP5447
#      - Product: Gree Inverter 4.0 Ton Floor Standing Air Conditioner GF-48TFIH
#      - Product: Gree GF-48TFIH AA Plus 4 Ton Inverter Cabinet Air Conditioner
#      - Product: Gree GF-24TFIH AA+ 2.0 ton inverter Wifi Cabinet Air Conditioner
#      - Product: Bosch KIV87NSF0M 10 CFT Built in Converterable Refrigerator
#      - Product: Dawlance DMD-7950 INOX 22 CFT Side By Side Inverter Refrigerator
#      - Product: Dawlance DMD-7950GD 22 CFT Side By Side Inverter Refrigerator
#      - Product: Dawlance DTM-7650 21 CFT Top Mount Inverter Refrigerator
#      - Product: Homage HRFVCM-47442 13 CFT Top Mount Refrigerator
#      - Product: Homage HRFVCM-47662 18 CFT Top Mount Refrigerator
#      - Product: PEL PRLP-22260 Life Pro 16 CFT Top Mount Refrigerator
#      - Product: Philips 800 Series Compact Air Purifier - AC0819
#      - Product: Xiaomi Smart Air Purifier Elite
#   Page 32: https://www.shophive.com/appliances?p=32
#      - Product: Philips 3-in-1 Purifier Fan and Heater AMF220/95
#      - Product: Haier HSU-13HFCP 1.1 Ton Inverter Air Conditioner
#      - Product: Haier HSU-13HFCS 1.0 Ton Inverter Air Conditioner
#      - Product: Haier Solar HSU Hybrid 3 T3 1.5 Ton Hot and Cool Inverter Air Conditioner
#      - Product: Haier HSU-19HFCS 1.6 Ton Inverter Air Conditioner
#      - Product: Haier HSU-24HFABT3 2.0 Ton Inverter Air Conditioner
#      - Product: Homage HCS-1221S 1.0 Ton Inverter Classic Air Conditioner
#      - Product: Homage HCS-1821S 1.5 Ton Heat & Cool Classic Air Conditioner
#      - Product: Homage HCS-2421S 2.0 Ton Inverter Air Conditioner
#      - Product: Midea 24HRFN 2.0 Ton Inverter Extreme Air Conditioner
#      - Product: Orient 24G 2.0 Ton Luner T3 Inverter Air Conditioner
#      - Product: Rays EAS-1820 1.5 Ton T3 Inverter Air Conditioner
#      - Product: Beurer LE-150 Air Dehumidifier
#      - Product: Beurer LE-250 Air Dehumidifier
#      - Product: TCL TAC-18T5 FreshIN 3.0 1.5 Ton Inverter Split Air Conditioner (2025)
#      - Product: Signature BR-30W 2 CFT Bed Room Size Refrigerator
#   Page 33: https://www.shophive.com/appliances?p=33
#   [Page Error]: HTTP Error 500: Internal Server Error
#
# Category: Cameras
#   Page 1: https://www.shophive.com/cameras?p=1
#      - Product: Sony PX470 Digital Voice Recorder PX Series
#      - Product: Canon EF 50mm f/1.8 STM Lens W.O
#      - Product: Mi 360 Home Security Camera 2K
#      - Product: Sigma 16mm f1.4 DC DN Contemporary Lens for Canon EF
#      - Product: Synco Vlogger Kit 1
#      - Product: Sigma 30mm f1.4 DC DN Contemporary Lens for Sony E
#      - Product: Sigma 56mm f1.4 DC DN Contemporary Lens for Sony E
#      - Product: Sigma 150-600mm f5-6.3 DG OS HSM Contemporary Lens for Canon EF
#      - Product: Sigma 60-600mm f4.5-6.3 DG OS HSM Sports Lens for Canon EF
#      - Product: Sigma MC-21 Mount Converter/Lens Adapter
#      - Product: Sigma USB Dock
#      - Product: Sigma 18-35mm f/1.8 DC HSM Art Lens For Canon EF
#      - Product: Sigma 14-24mm f2.8 DG HSM Art Lens For Nikon F
#      - Product: Sigma 24-70mm f/2.8 DG DN Art Lens for Sony E
#      - Product: Sigma 20mm f1.4 DG HSM Art Lens for Sony E
#      - Product: Sigma 24mm f1.4 DG HSM Art Lens for Canon EF
#   Page 2: https://www.shophive.com/cameras?p=2
#      - Product: Sigma 35mm f1.2 DG DN Art Lens for Sony E
#      - Product: Sigma 35mm f1.4 DG HSM Art Lens for Canon EF
#      - Product: Sigma 40mm f1.4 DG HSM Art Lens for Sony E
#      - Product: Sigma 70mm f2.8 DG Macro Art Lens for Sony E
#      - Product: Sigma 105mm f2.8 DG DN Macro Art Lens for Sony E
#      - Product: Nikon Z5 Nikkor Mirrorless Digital Camera 24-200mm Kit
#      - Product: Nikon Z5 24-50mm Lens Kit
#      - Product: Nikon AF-S Teleconverter TC-14E II Lens
#      - Product: Nikon AF-S Teleconverter TC-17E II Lens
#      - Product: Nikon AF-S Teleconverter TC-14E III
#      - Product: Nikon NIKKOR Z 20mm f/1.8 S Lens
#      - Product: Nikon NIKKOR Z 24mm f/1.8 S Lens
#      - Product: Nikon NIKKOR Z 24-70mm f/2.8 S Lens
#      - Product: DJI Motion Controller
#      - Product: Nikon Z6 Mirrorless Digital Camera (Body Only)
#      - Product: Nikon Z7 Mirrorless Digital Camera with 24-70mm Lens and FTZ Adapter Kit
#   Page 3: https://www.shophive.com/cameras?p=3
#      - Product: Nikon Coolpix Nikon P1000 Super-Telephoto Digital Camera
#      - Product: Nikon Coolpix B500
#      - Product: Nikon NIKKOR Z 85mm f/1.8 S Lens
#      - Product: Nikon Z TC-1.4x Teleconverter
#      - Product: Nikon Z TC-2x Teleconverter
#      - Product: Sony FE 16-35mm f/2.8 GM Lens
#      - Product: Sony FE 24-70mm f/2.8 GM Lens (SEL2470GM)
#   [Product Error]: HTTP Error 500: Internal Server Error
#      - Product: Tamron 28-300mm f/3.5-6.3 Di VC PZD Lens
#      - Product: Tamron 17-28mm f 2.8 Di iii RXD Mount
#      - Product: Tamron 11-20mm f/2.8 Di III-A RXD Lens for Sony E
#      - Product: Tamron 70-180mm f/2.8 Di III VXD Lens for Sony E
#      - Product: Tamron 35-150mm f/2-2.8 Di III VXD Lens for Sony E
#      - Product: Tamron 28-75mm f/2.8 Di III VXD G2 Lens for Sony E
#      - Product: Tamron 35mm f/2.8 Di III OSD M 1:2 Lens for Sony E
#      - Product: Tamron 24mm f/2.8 Di III OSD M 1:2 Lens for Sony E
#   Page 4: https://www.shophive.com/cameras?p=4
#      - Product: Tamron 20mm f/2.8 Di III OSD M 1:2 Lens for Sony E
#      - Product: Tamron SP 70-300mm f/4-5.6 Di VC USD Telephoto Zoom Lens
#      - Product: Tamron 150-600mm f/5-6.3 Di VC USD G2 Lens
#      - Product: DJI Action 2
#      - Product: DJI RS 2 Gimbal Stabilizer
#      - Product: Elgato Ring Light
#      - Product: Sony Alpha ILCE-7M3 Full-Frame 24.2MP Mirrorless Camera Body
#      - Product: Canon EOS RP Mirrorless Camera Body
#      - Product: Wyze WHMS1 Wi-Fi Motion Sensor - White
#      - Product: Canon EOS R5 Mirrorless Digital Camera with 24-105mm f/4L Lens
#      - Product: Canon EOS R5 Mirrorless Digital Camera Body RF 600mm f/11 IS STM Lens
#      - Product: Canon EOS R5 Body (2.4GHz) With RF800mm F/11 Stm Lens
#      - Product: Canon EOS R6 Mirrorless Digital Camera (Body Only)
#      - Product: Canon Extender RF 2x
#      - Product: Canon Extender RF 1.4x
#      - Product: Canon EOS 3000D Digital Camera 18-55 DC III Lens
#   Page 5: https://www.shophive.com/cameras?p=5
#      - Product: Canon EOS R Mirrorless Digital Camera with 24-105mm f/4-7.1 Lens
#      - Product: Canon EOS M50 Mark II Mirrorless Digital Camera with 15-45mm Lens (Black)
#      - Product: Canon RF 85mm f/2 Macro IS STM Lens
#      - Product: Studio Slave Bulb Holder
#   [Product Error]: HTTP Error 500: Internal Server Error
#      - Product: FeelWorld F5 5.0" Full HD HDMI On-Camera Monitor with 4K Support and Tilt Arm
#      - Product: JMARY RING LIGHT FM-18R 18 inch
#      - Product: Impact 5-in-1 Collapsible Circular Reflector Disc (42")
#      - Product: Boya BY-WM3D Wireless Microphone
#      - Product: Tamron SP 35mm f/1.8 Di VC USD Lens for Nikon F
#      - Product: Tamron SP 70-200mm f/2.8 Di VC USD G2 Lens
#      - Product: Tamron 18-200mm f/3.5-6.3 Di II VC Lens
#      - Product: Nikon NIKKOR Z 35mm f/1.8 S Lens
#      - Product: Nikon Z 5 Mirrorless Digital Camera (Body Only)
#      - Product: Sony Alpha a6400 Mirrorless Digital Camera (Body Only)
#      - Product: Sony Alpha a7S III Mirrorless Digital Camera (Body Only)
#   Page 6: https://www.shophive.com/cameras?p=6
#   [Page Error]: HTTP Error 500: Internal Server Error
#
# Category: Office Products
#   Page 1: https://www.shophive.com/office-products?p=1
#      - Product: Deli E15130 Barcode Scanner Stand
#      - Product: Logitech Smart Dock Video Conferencing
#      - Product: Barco Click Share C‑10 Gen 2 Presentation
#      - Product: Barco Click Share CX‑20 Wireless Conferencing System
#      - Product: APC SUA1000I Smart UPS
#      - Product: APC SUA1500I Smart UPS & serial 230V
#      - Product: Ugreen HDMI Male to Female Adapter Down
#      - Product: Aurora AS2220CD Paper Shredder
#      - Product: Mi City Backpack 2
#      - Product: Aurora Electronic Safe BS-AD53B
#      - Product: Aurora Electronic Safe BS-AD63B
#      - Product: Aurora Fireproof Safe YB-350ALE
#      - Product: Aurora Fireproof Safe 3 Drawer Safe AFS-13E
#      - Product: Aurora Metal Key Box 30K-45
#   [Product Error]: HTTP Error 500: Internal Server Error
#      - Product: Panasonic KX-TG3611 Cordless Phone
#   Page 2: https://www.shophive.com/office-products?p=2
#      - Product: APC Smart-SRT 10000XLI 10kVA, 230/400V, LCD UPS
#      - Product: Deli E9945 Paper Shredder
#      - Product: Deli E9911 Paper Shredder
#      - Product: Deli E9952 Paper Shredder
#      - Product: Deli E9903 Paper Shredder
#      - Product: Deli E9918 Paper Shredder
#      - Product: Deli 14403 Paper Shredder
#      - Product: Deli 9909 Paper Shredder
#      - Product: Deli E801P Thermal Receipt Printer
#      - Product: Aurora AS2030CD Paper Shredder with1hr continous operation
#   [Product Error]: HTTP Error 500: Internal Server Error
#      - Product: HSM Shred Star X5 (CD Cutting)
#      - Product: UGreen 80910 Bluetooth FM Transmitter Car Adaptor
#   [Product Error]: HTTP Error 500: Internal Server Error
#      - Product: Aurora AS1230CD Paper Shredder
#      - Product: Aurora AS1225CD Paper Shredder
#   Page 3: https://www.shophive.com/office-products?p=3
#      - Product: Aurora AS106C Paper Shredder
#      - Product: Aurora AS1430CD Paper Shredder
#      - Product: Aurora AS792CE Paper Shredder
#      - Product: Aurora Electronic Safe AES 1230D
#      - Product: Aurora Fireproof Safe-YB 700ALE
#      - Product: Travel Blue Double Pod
#      - Product: HSM ShredStar X8
#      - Product: HSM ShredStar S10 6MM (CD Cutting)
#      - Product: Deli E3747 Pro Time Attendance Machine
#      - Product: Deli E3758 Time Attendance Machine
#      - Product: Jasco J2500s 2.5KVA Green Series Generator
#      - Product: Jasco J3000s 3 KVA Green Series Generator
#      - Product: Jasco J8000s 8 KVA Green Series Generators
#      - Product: Onten 9175s Type C To Dual Hdmi Adapter
#   [Product Error]: HTTP Error 500: Internal Server Error
#   [Product Error]: HTTP Error 500: Internal Server Error
#   Page 4: https://www.shophive.com/office-products?p=4
#      - Product: Deli E9947 Paper Shredder
#      - Product: Cisco CP-7821-K9 UC Phone 7821
#      - Product: Cisco CP-8841-K9 Cisco IP Phone 8841
#      - Product: Jasco J9000DC 8 KVA Golden Series Generator
#      - Product: Jasco RG-5600 Rigid 3 KVA Generator
#      - Product: Camelion CMS-118 8 Sockets Extension Lead 3 Meters
#      - Product: Camelion CMS-114 4 Outlet Power Socket Extension 3m Cable
#      - Product: Camelion CMS-541 4 Sockets Extension Lead 3M Cable
#      - Product: Camelion CMS-161A 6 Sockets Extension Lead 3m Cable
#      - Product: Camelion CMS 168 Power Extension 6 Port 4M Cable
#      - Product: Camelion CMS 148 Power Extension Lead 4 Ports & 5 Meters Cable
#      - Product: Camelion CMS 241U Super Heavy Duty Extension Wire WITH USB EXT WIRE 3M Cable
#      - Product: Target TG-36S Paper Shredder
#      - Product: Target TG-210M Paper Shredder
#      - Product: Target TG-150 X Paper Shredder
#      - Product: Anker Lighting 3.5mm & Charging Adapter White - A3520H22
#   Page 5: https://www.shophive.com/office-products?p=5
#      - Product: APC Surt6000xli Smart UPS
#      - Product: APC Srt5000xli Smart UPS
#      - Product: APC Srt3000xli Smart UPS
#      - Product: HP 90W USB-C Power Adapter
#      - Product: HP Smart Slim Power Adapter 150 Watt
#      - Product: Vertiv Psa650-Soho Ups
#      - Product: Baseus Wireless Bluetooth 5.3 Adapter BA07
#      - Product: Amaze A120 USB - C to 4K HDMI Adapter
#      - Product: KSTAR UA60 600VA Line Interactive UPS
#      - Product: KStar UA120 Line 1200VA/720W Interactive UPS
#      - Product: KStar UA200 Line 2000VA Interactive UPS
#      - Product: APC SRV1KI Easy On-Line SRV 1000VA 230V UPS
#      - Product: APC SRV2KI Easy On-Line SRV 2000VA 230V UPS
#      - Product: APC SRV3KI Easy On-Line SRV 3000VA 230V UPS
#      - Product: APC SRV6KI Easy SRV 6000VA 230V UPS
#      - Product: APC SRV10KI Easy SRV 10000VA 230V UPS
#   Page 6: https://www.shophive.com/office-products?p=6
#      - Product: HP Paper Shredder W1508CC
#      - Product: HP 12CC OneShred Paper Shredder
#      - Product: HP W2518CC Paper Shredder
#      - Product: Aurora Electronic Safe Aes-2500K White
#      - Product: UGreen PD 30W Outlet Adapter 4 IN 1 Fast Charger
#      - Product: UGreen USB To Audio Jack USB External Sound Card 3.5MM Audio Adapter
#      - Product: Deli ET053 Paper Shredder
#      - Product: Deli E14400 Paper Shredder
#      - Product: Target TG-168 Paper Shredder
#      - Product: Deli ET089 12 Sheets 32L Bin Paper Shredder
#   [Product Error]: HTTP Error 500: Internal Server Error
#      - Product: Jasco RG-6000 Rigid 3.5 KVA Generator
#      - Product: Deli ET102SC Paper Shredder
#      - Product: Deli ET022 Paper Shredder
#      - Product: Deli ET054 Paper Shredder (Micro Cut)
#      - Product: Deli ET058 Paper Shredder (Micro Cut)
#   Page 7: https://www.shophive.com/office-products?p=7
#      - Product: Deli ET081 Paper Shredder
#   [Product Error]: HTTP Error 500: Internal Server Error
#      - Product: Speed x BT500M Mini Portable Bluetooth+USB Printer 58MM
#      - Product: Speed X Bt450m Mini Portable Bluetooth+Usb Printer 58mm
#      - Product: XPrinter XP-Q805K USB Interface 230mm/s Printing Speed
#      - Product: Panasonic KX-TG3712SX Dual Cordless Landline Phone
#      - Product: Deli ET014 Paper Shredder
#      - Product: Deli ET001 Paper Shredder
#      - Product: Aurora Electronic Safe AES-1300D
#      - Product: Aurora Fingerprint Safe AFS-1300K
#      - Product: Aurora Fingerprint Safe AFS-1500K
#      - Product: Aurora Electronic Safe AES-1250D
#      - Product: Panasonic KX-TS580MX
#      - Product: Panasonic KX-TS7703
#      - Product: Aurora As2030Cd with 30 Minutes Continous Operation Paper Shredder
#      - Product: Aurora AS680SB Paper Shredder
#   Page 8: https://www.shophive.com/office-products?p=8
#      - Product: Aurora AS1540CD Paper Shredder
#      - Product: Aurora Electronic Safe AES-1500D
#      - Product: Aurora Electronic Safe AES-5600D
#      - Product: Aurora Key Box 20K-20 - 20 Keys
#      - Product: Aurora Key Box 25K-48
#      - Product: Travel Blue High Security Twin Combination Padlocks
#      - Product: Travel Blue Easy Read Combination Lock
#      - Product: Travel Blue Travel Shoulder Wallet
#      - Product: Travel Blue The Mini Bag
#      - Product: Travel Blue Triple Pod
#      - Product: Travel blue Comfi Pillow
#      - Product: Travel BLue Magnifying Galss With LED
#      - Product: Aurora Electronic Safe AES-1800D
#      - Product: Aurora Electronic Safe ABS-660SC/530ALM
#      - Product: Aurora Electronic Elegant Safe AES-800ALM
#      - Product: Aurora Key Box 30K-93
#   Page 9: https://www.shophive.com/office-products?p=9
#      - Product: Aurora TC-56 5600KM Intelligent Safe
#      - Product: Travel Blue Rfid Pockets
#      - Product: Aurora Gun Safe 1450BK
#      - Product: Aurora Electronic Safe ABS-AD42B
#      - Product: Targus Smart Surge Protector 4
#      - Product: Aurora YB-500ALE Fireproof Safe
#      - Product: Aurora YB-920ALE Fireproof Safe
#      - Product: Travel Blue Suitcase Padlock Pack Of 2 - Bright Yellow
#      - Product: Aurora Fireproof Safe YB-530ALE
#      - Product: Aurora AS1530CM Cross Cut Shredder
#      - Product: Aurora AS152CM Cross Cut Shredder
#      - Product: Travel Blue Security Neck Wallet Black
#      - Product: Targus APK0102AP Travel Adaptor
#      - Product: Targus DOCK412AP USB-C Travel Dock With Power Pass-Through
#      - Product: Panasonic KX-TS500MX Corded Landline Phone
#      - Product: Panasonic KX-TS560MX Corded Telephone
#   Page 10: https://www.shophive.com/office-products?p=10
#   [Page Error]: HTTP Error 500: Internal Server Error
# Saved to 'products.json'
# Saved to 'products.csv'
